# %% [markdown]
# ![](./Images/image.png)

# %% [markdown]
# ### Deployment de Deep Learning com YOLO

# %%
# Use o mlflow para uma versão compatível
# %pip install mlflow==2.21.3
# Out:
# Collecting mlflow==2.21.3
#   Downloading mlflow-2.21.3-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==2.21.3 (from mlflow==2.21.3)
#   Downloading mlflow_skinny-2.21.3-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow==2.21.3) (3.1.2)
# Requirement already satisfied: Jinja2<4,>=2.11 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow==2.21.3) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow==2.21.3) (1.16.5)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow==2.21.3) (7.1.0)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow==2.21.3) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow==2.21.3) (23.0.0)
# Collecting markdown<4,>=3.3 (from mlflow==2.21.3)
#   Downloading markdown-3.9-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: matplotlib<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow==2.21.3) (3.8.4)
# Requirement already satisfied: numpy<3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow==2.21.3) (2.2.6)
# Requirement already satisfied: pandas<3 in /databricks/python3/lib/python3.12/site-packages (from mlflow==2.21.3) (1.5.3)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow==2.21.3) (15.0.2)
# Requirement already satisfied: scikit-learn<2 in /databricks/python3/lib/python3.12/site-packages (from mlflow==2.21.3) (1.4.2)
# Requirement already satisfied: scipy<2 in /databricks/python3/lib/python3.12/site-packages (from mlflow==2.21.3) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow==2.21.3) (2.0.43)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (0.49.0)
# Requirement already satisfied: fastapi<1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (3.1.37)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (7.0.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (1.31.1)
# Requirement already satisfied: packaging<25 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (24.1)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (5.29.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (2.11.9)
# Requirement already satisfied: pyyaml<7,>=5.1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (6.0.1)
# Requirement already satisfied: requests<3,>=2.17.3 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (2.32.2)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny==2.21.3->mlflow==2.21.3) (0.34.0)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow==2.21.3) (1.3.10)
# Requirement already satisfied: urllib3>=1.26.0 in /databricks/python3/lib/python3.12/site-packages (from docker<8,>=4.0.0->mlflow==2.21.3) (2.2.2)
# Requirement already satisfied: blinker>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from Flask<4->mlflow==2.21.3) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from Flask<4->mlflow==2.21.3) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from Flask<4->mlflow==2.21.3) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from Flask<4->mlflow==2.21.3) (3.1.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from graphene<4->mlflow==2.21.3) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from graphene<4->mlflow==2.21.3) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /databricks/python3/lib/python3.12/site-packages (from graphene<4->mlflow==2.21.3) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.21.3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.21.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.21.3) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.21.3) (1.4.4)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.21.3) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow==2.21.3) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas<3->mlflow==2.21.3) (2024.1)
# Collecting numpy<3 (from mlflow==2.21.3)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: joblib>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn<2->mlflow==2.21.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn<2->mlflow==2.21.3) (2.2.0)
# Requirement already satisfied: greenlet>=1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.21.3) (3.2.4)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow==2.21.3) (2.38.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /databricks/python3/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny==2.21.3->mlflow==2.21.3) (0.46.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.21.3->mlflow==2.21.3) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.21.3->mlflow==2.21.3) (3.17.0)
# Requirement already satisfied: deprecated>=1.2.6 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow==2.21.3) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow==2.21.3) (0.52b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow==2.21.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow==2.21.3) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow==2.21.3) (0.4.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow==2.21.3) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow==2.21.3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow==2.21.3) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow==2.21.3) (2024.6.2)
# Requirement already satisfied: h11>=0.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny==2.21.3->mlflow==2.21.3) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /databricks/python3/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow==2.21.3) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.21.3->mlflow==2.21.3) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow==2.21.3) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow==2.21.3) (4.9)
# Requirement already satisfied: anyio<5,>=3.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.3->mlflow==2.21.3) (4.11.0)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.3->mlflow==2.21.3) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow==2.21.3) (0.4.8)
# Downloading mlflow-2.21.3-py3-none-any.whl (28.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.2/28.2 MB 77.2 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.21.3-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 67.6 MB/s eta 0:00:00
# Downloading markdown-3.9-py3-none-any.whl (107 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy, markdown, mlflow-skinny, mlflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
#   Attempting uninstall: mlflow-skinny
#     Found existing installation: mlflow-skinny 3.4.0
#     Uninstalling mlflow-skinny-3.4.0:
#       Successfully uninstalled mlflow-skinny-3.4.0
#   Attempting uninstall: mlflow
#     Found existing installation: mlflow 3.4.0
#     Uninstalling mlflow-3.4.0:
#       Successfully uninstalled mlflow-3.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed markdown-3.9 mlflow-2.21.3 mlflow-skinny-2.21.3 numpy-1.26.4
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# Instale a biblioteca necessária
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (8.3.203)
# Requirement already satisfied: numpy>=1.23.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /databricks/python3/lib/python3.12/site-packages (from ultralytics) (3.8.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /databricks/python3/lib/python3.12/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /databricks/python3/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /databricks/python3/lib/python3.12/site-packages (from ultralytics) (2.32.2)
# Requirement already satisfied: scipy>=1.4.1 in /databricks/python3/lib/python3.12/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil in /databricks/python3/lib/python3.12/site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: polars in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from ultralytics) (1.33.1)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting numpy>=1.23.0 (from ultralytics)
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.8.0)
# Requirement already satisfied: sympy>=1.13.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# databricks-connect 16.4.2 requires numpy<2,>=1.15, but you have numpy 2.2.6 which is incompatible.
# pyarrow 15.0.2 requires numpy<2,>=1.16.6, but you have numpy 2.2.6 which is incompatible.
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# Importe as bibliotecas necessárias
from ultralytics import YOLO

import mlflow.pyfunc
from mlflow.models.signature import infer_signature

import numpy as np
import pandas as pd
import base64
import io
from PIL import Image

# %%
# Carregue o modelo pré-treinado
model = YOLO("yolo11s.pt")

# %%
# Use a imagem da web como exemplo
import requests
image=requests.get("https://media.macphun.com/img/uploads/customer/blog/1355/15541861425ca2ff9ecf7899.00222453.jpg?q=85&w=850").content

from io import BytesIO
image_bytes = BytesIO(image)

from PIL import Image
image_pil = Image.open(image_bytes)

# %%
# Exiba a imagem
display(image_pil)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=850x566>

# %%
results = model([image_pil])  # Usa o array numpy

# Crie os resultados para cada objeto identificado
for result in results:
    boxes = result.boxes
    masks = result.masks
    keypoints = result.keypoints
    probs = result.probs
    obb = result.obb
    result.show()
# Out:
# 0: 448x640 1 person, 6 cars, 1 bus, 5 traffic lights, 831.9ms
# Speed: 10.0ms preprocess, 831.9ms inference, 33.6ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=850x566>

# %%
# Crie um wrapper
class YoloWrapper(mlflow.pyfunc.PythonModel):
    def load_context(self, context):
        self.model = YOLO(context.artifacts["model_path"])

    def predict(self, context, model_input):

        # Suporta DataFrame ou dicionário
        if hasattr(model_input, 'iloc'):
            b64 = model_input.iloc[0]['image_base64']
        else:
            b64 = model_input['image_base64']

        # Decodifica base64 em bytes
        img_bytes = base64.b64decode(b64)
        image = Image.open(io.BytesIO(img_bytes)).convert("RGB")
        image_np = np.array(image)
        
        # Faz predição
        results = self.model(image_np)

        # Salva a imagem anotada em memória
        output_buffer = io.BytesIO()

        # YOLO .plot()
        annotated_img = results[0].plot() if hasattr(results[0], "plot") else results[0].imgs[0]
        annotated_pil = Image.fromarray(annotated_img)
        annotated_pil.save(output_buffer, format="JPEG")
        output_b64 = base64.b64encode(output_buffer.getvalue()).decode("utf-8")
        return {"predicted_image_base64": output_b64}

# Crie um arquivo temporário
temp_path = "/tmp/yolo11s.pt"
model.save(temp_path)

# Crie um input de exemplo
img_url = "https://cdn.pixabay.com/photo/2020/04/09/10/47/car-5020870_1280.jpg"

# Baixe e codifique a imagem em base64
img_response = requests.get(img_url)
b64_img = base64.b64encode(img_response.content).decode("utf-8")

input_example = pd.DataFrame({
    "image_base64": [b64_img]
})

# Exemplo de saída para signature
predicted_example = pd.DataFrame({"predicted_image_base64": ["exemplo_base64"]})
signature = infer_signature(input_example, predicted_example)

with mlflow.start_run() as run:
    mlflow.pyfunc.log_model(
        artifact_path="model", 
        python_model=YoloWrapper(),
        artifacts={"model_path": temp_path},
        pip_requirements=["ultralytics", "pillow", "numpy"],
        input_example=input_example,
        signature=signature
    )
# Out:
# /databricks/python/lib/python3.12/site-packages/mlflow/pyfunc/utils/data_validation.py:186: UserWarning: Add type hints to the `predict` method to enable data validation and automatic signature inference during model logging. Check https://mlflow.org/docs/latest/model/python_model.html#type-hint-usage-in-pythonmodel for more details.
#   color_warning(
# 2025/09/24 18:34:14 INFO mlflow.pyfunc: Validating input example against model signature
# 0: 448x640 1 person, 2 cars, 2 potted plants, 510.9ms
# Speed: 23.0ms preprocess, 510.9ms inference, 30.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Abra a execução do MLflow, registre o modelo (de preferência sempre no Unity Catalog - basta colocar o nome que deseja e clicar em Register). Em seguida, sirva o modelo. Conforme abaixo

# %% [markdown]
# ![YOLORegistry.png](./YOLORegistry.png "YOLORegistry.png")

# %% [markdown]
# ![YOLOUC.png](./YOLOUC.png "YOLOUC.png")

# %% [markdown]
# ![endpointYOLO.png](./endpointYOLO.png "endpointYOLO.png")

# %%
import requests
import base64
import json
from PIL import Image
from io import BytesIO
import getpass

# Insira o token
token = getpass.getpass("Digite seu token: ")

# URL da imagem pública
img_url = "https://cdn.pixabay.com/photo/2020/04/09/10/47/car-5020870_1280.jpg"

# Baixa e codifica a imagem em base64
img_response = requests.get(img_url)
b64_img = base64.b64encode(img_response.content).decode("utf-8")

payload = {
    "dataframe_split": {
        "columns": ["image_base64"],
        "data": [[b64_img]]
    }
}

headers = {
    "Authorization": f"Bearer {token}",  # Substitua pelo seu token
    "Content-Type": "application/json"
}

url = "https://e2-demo-field-eng.cloud.databricks.com/serving-endpoints/yoloendpointtestebaraldi/invocations"

response = requests.post(url, headers=headers, data=json.dumps(payload))
result = response.json()

# O campo retornado contém a imagem anotada em base64
display(Image.open(BytesIO(base64.b64decode(result["predictions"]["predicted_image_base64"]))))
# Out:
# Digite seu token:  [REDACTED]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x853>

# %% [markdown]
# ### Deployment com GenAI Multimodal com Modelo na Plataforma da Databricks

# %%
# Instale as bibliotecas necessárias
# %pip install langchain-community langchain-core databricks-langchain
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-core
#   Downloading langchain_core-0.3.76-py3-none-any.whl.metadata (3.7 kB)
# Collecting databricks-langchain
#   Downloading databricks_langchain-0.8.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting langchain<2.0.0,>=0.3.27 (from langchain-community)
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from langchain-community) (2.0.43)
# Collecting requests<3,>=2.32.5 (from langchain-community)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML>=5.3 in /databricks/python3/lib/python3.12/site-packages (from langchain-community) (6.0.1)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.12.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /databricks/python3/lib/python3.12/site-packages (from langchain-community) (8.2.2)
# Collecting dataclasses-json<0.7,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from langchain-community) (2.11.0)
# Collecting langsmith>=0.1.125 (from langchain-community)
#   Downloading langsmith-0.4.30-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in /databricks/python3/lib/python3.12/site-packages (from langchain-core) (24.1)
# Requirement already satisfied: pydantic>=2.7.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from langchain-core) (2.11.9)
# Collecting databricks-ai-bridge>=0.8.0 (from databricks-langchain)
#   Downloading databricks_ai_bridge-0.8.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting databricks-sdk>=0.65.0 (from databricks-langchain)
#   Downloading databricks_sdk-0.66.0-py3-none-any.whl.metadata (39 kB)
# Collecting databricks-vectorsearch>=0.50 (from databricks-langchain)
#   Downloading databricks_vectorsearch-0.59-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: mlflow>=2.20.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from databricks-langchain) (2.21.3)
# Collecting openai>=1.99.9 (from databricks-langchain)
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Collecting unitycatalog-langchain>=0.2.0 (from unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain)
#   Downloading unitycatalog_langchain-0.2.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.6.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Requirement already satisfied: mlflow-skinny>=2.19.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from databricks-ai-bridge>=0.8.0->databricks-langchain) (2.21.3)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (from databricks-ai-bridge>=0.8.0->databricks-langchain) (1.5.3)
# Collecting tabulate>=0.9.0 (from databricks-ai-bridge>=0.8.0->databricks-langchain)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting tiktoken>=0.8.0 (from databricks-ai-bridge>=0.8.0->databricks-langchain)
#   Downloading tiktoken-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk>=0.65.0->databricks-langchain) (2.38.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-vectorsearch>=0.50->databricks-langchain) (5.29.4)
# Collecting deprecation>=2 (from databricks-vectorsearch>=0.50->databricks-langchain)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain<2.0.0,>=0.3.27->langchain-community)
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith>=0.1.125->langchain-community)
#   Downloading orjson-3.11.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith>=0.1.125->langchain-community)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: zstandard>=0.23.0 in /databricks/python3/lib/python3.12/site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: Flask<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (3.1.2)
# Requirement already satisfied: Jinja2<4,>=2.11 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (3.1.6)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (1.16.5)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (7.1.0)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (3.9)
# Requirement already satisfied: matplotlib<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (3.8.4)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (15.0.2)
# Requirement already satisfied: scikit-learn<2 in /databricks/python3/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (1.4.2)
# Requirement already satisfied: scipy<2 in /databricks/python3/lib/python3.12/site-packages (from mlflow>=2.20.1->databricks-langchain) (1.13.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (8.1.7)
# Requirement already satisfied: cloudpickle<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (3.0.0)
# Requirement already satisfied: fastapi<1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (0.115.12)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (3.1.37)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (7.0.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (1.31.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (0.5.3)
# Requirement already satisfied: uvicorn<1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (0.34.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from openai>=1.99.9->databricks-langchain) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.99.9->databricks-langchain) (1.9.0)
# Collecting jiter<1,>=0.4.0 (from openai>=1.99.9->databricks-langchain)
#   Downloading jiter-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.12/site-packages (from openai>=1.99.9->databricks-langchain) (1.3.0)
# Collecting tqdm>4 (from openai>=1.99.9->databricks-langchain)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from pydantic>=2.7.4->langchain-core) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.32.5->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.32.5->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.32.5->langchain-community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.32.5->langchain-community) (2024.6.2)
# Requirement already satisfied: greenlet>=1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.4)
# Collecting unitycatalog-ai (from unitycatalog-langchain>=0.2.0->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain)
#   Downloading unitycatalog_ai-0.3.2-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from alembic!=1.10.0,<2->mlflow>=2.20.1->databricks-langchain) (1.3.10)
# Requirement already satisfied: blinker>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from Flask<4->mlflow>=2.20.1->databricks-langchain) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from Flask<4->mlflow>=2.20.1->databricks-langchain) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from Flask<4->mlflow>=2.20.1->databricks-langchain) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from Flask<4->mlflow>=2.20.1->databricks-langchain) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk>=0.65.0->databricks-langchain) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk>=0.65.0->databricks-langchain) (4.9)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from graphene<4->mlflow>=2.20.1->databricks-langchain) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from graphene<4->mlflow>=2.20.1->databricks-langchain) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /databricks/python3/lib/python3.12/site-packages (from graphene<4->mlflow>=2.20.1->databricks-langchain) (2.9.0.post0)
# Requirement already satisfied: httpcore==1.* in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.20.1->databricks-langchain) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.20.1->databricks-langchain) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.20.1->databricks-langchain) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.20.1->databricks-langchain) (1.4.4)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.20.1->databricks-langchain) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib<4->mlflow>=2.20.1->databricks-langchain) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas->databricks-ai-bridge>=0.8.0->databricks-langchain) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn<2->mlflow>=2.20.1->databricks-langchain) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn<2->mlflow>=2.20.1->databricks-langchain) (2.2.0)
# Collecting regex>=2022.1.18 (from tiktoken>=0.8.0->databricks-ai-bridge>=0.8.0->databricks-langchain)
#   Downloading regex-2025.9.18-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community) (1.0.0)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.12/site-packages (from unitycatalog-ai->unitycatalog-langchain>=0.2.0->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain) (1.6.0)
# Collecting unitycatalog-client (from unitycatalog-ai->unitycatalog-langchain>=0.2.0->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain)
#   Downloading unitycatalog_client-0.3.0-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: databricks-connect<17.1,>=15.1.0 in /databricks/python3/lib/python3.12/site-packages (from unitycatalog-ai[databricks]; extra == "databricks"->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain) (16.4.2)
# Requirement already satisfied: googleapis-common-protos>=1.56.4 in /databricks/python3/lib/python3.12/site-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai[databricks]; extra == "databricks"->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain) (1.69.2)
# Requirement already satisfied: grpcio-status>=1.59.3 in /databricks/python3/lib/python3.12/site-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai[databricks]; extra == "databricks"->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain) (1.71.0)
# Requirement already satisfied: grpcio>=1.59.3 in /databricks/python3/lib/python3.12/site-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai[databricks]; extra == "databricks"->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain) (1.71.0)
# Requirement already satisfied: py4j==0.10.9.9 in /databricks/python3/lib/python3.12/site-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai[databricks]; extra == "databricks"->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain) (0.10.9.9)
# Requirement already satisfied: setuptools>=68.0.0 in /usr/local/lib/python3.12/dist-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai[databricks]; extra == "databricks"->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain) (75.8.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai[databricks]; extra == "databricks"->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain) (1.16.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /databricks/python3/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (0.46.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (3.17.0)
# Requirement already satisfied: deprecated>=1.2.6 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (0.52b1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk>=0.65.0->databricks-langchain) (0.4.8)
# Collecting aiohttp-retry>=2.8.3 (from unitycatalog-client->unitycatalog-ai->unitycatalog-langchain>=0.2.0->unitycatalog-langchain[databricks]>=0.2.0->databricks-langchain)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /databricks/python3/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.8.0->databricks-langchain) (5.0.0)
# Downloading langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 66.6 MB/s eta 0:00:00
# Downloading langchain_core-0.3.76-py3-none-any.whl (447 kB)
# Downloading databricks_langchain-0.8.0-py3-none-any.whl (27 kB)
# Downloading aiohttp-3.12.15-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 90.9 MB/s eta 0:00:00
# Downloading databricks_ai_bridge-0.8.0-py3-none-any.whl (18 kB)
# Downloading databricks_sdk-0.66.0-py3-none-any.whl (717 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 717.5/717.5 kB 39.2 MB/s eta 0:00:00
# Downloading databricks_vectorsearch-0.59-py3-none-any.whl (15 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.5 MB/s eta 0:00:00
# Downloading langsmith-0.4.30-py3-none-any.whl (386 kB)
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.6/948.6 kB 49.8 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading unitycatalog_langchain-0.2.0-py3-none-any.whl (5.4 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading frozenlist-1.7.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
# Downloading jiter-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (347 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.6.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Downloading orjson-3.11.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (132 kB)
# Downloading propcache-0.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (224 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading tiktoken-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.20.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (355 kB)
# Downloading unitycatalog_ai-0.3.2-py3-none-any.whl (66 kB)
# Downloading regex-2025.9.18-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (802 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.0/802.0 kB 42.7 MB/s eta 0:00:00
# Downloading unitycatalog_client-0.3.0-py3-none-any.whl (159 kB)
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Installing collected packages: typing-inspect, tqdm, tabulate, requests, regex, propcache, orjson, multidict, marshmallow, jsonpointer, jiter, frozenlist, deprecation, aiohappyeyeballs, yarl, tiktoken, requests-toolbelt, jsonpatch, dataclasses-json, aiosignal, openai, langsmith, databricks-sdk, aiohttp, langchain-core, aiohttp-retry, unitycatalog-client, langchain-text-splitters, unitycatalog-ai, langchain, databricks-vectorsearch, databricks-ai-bridge, langchain-community, unitycatalog-langchain, databricks-langchain
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.2
#     Not uninstalling requests at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: databricks-sdk
#     Found existing installation: databricks-sdk 0.49.0
#     Not uninstalling databricks-sdk at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-539a7227-edbe-49fc-bb1e-65618db36995
#     Can't uninstall 'databricks-sdk'. No files were found to uninstall.
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiohttp-retry-2.9.1 aiosignal-1.4.0 databricks-ai-bridge-0.8.0 databricks-langchain-0.8.0 databricks-sdk-0.66.0 databricks-vectorsearch-0.59 dataclasses-json-0.6.7 deprecation-2.1.0 frozenlist-1.7.0 jiter-0.11.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.27 langchain-community-0.3.29 langchain-core-0.3.76 langchain-text-splitters-0.3.11 langsmith-0.4.30 marshmallow-3.26.1 multidict-6.6.4 openai-1.109.1 orjson-3.11.3 propcache-0.3.2 regex-2025.9.18 requests-2.32.5 requests-toolbelt-1.0.0 tabulate-0.9.0 tiktoken-0.11.0 tqdm-4.67.1 typing-inspect-0.9.0 unitycatalog-ai-0.3.2 unitycatalog-client-0.3.0 unitycatalog-langchain-0.2.0 yarl-1.20.1
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# Importe as bibliotecas necessárias
import base64
from langchain_core.messages import SystemMessage, HumanMessage
from databricks_langchain import ChatDatabricks
import getpass
import mlflow.langchain
from io import BytesIO
from langchain_core.prompts.chat import ChatPromptTemplate
import requests
from PIL import Image

# %%
# Ative o autolog
mlflow.langchain.autolog()


# Baixe e processe a imagem
img_url = "https://cdn.pixabay.com/photo/2020/04/09/10/47/car-5020870_1280.jpg"
img_response = requests.get(img_url)
img = Image.open(BytesIO(img_response.content)).convert("RGB")
img = img.resize((224, 224))
buffer = BytesIO()
img.save(buffer, format="JPEG", quality=70)
buffer.seek(0)
img_base64 = base64.b64encode(buffer.read()).decode("utf-8")

# Crie o template multimodal conforme documentação
template = ChatPromptTemplate.from_messages(
    [
        ("system", "Você é um assistente que conta carros em imagens."),
        (
            "human",
            [
                {"type": "text", "text": "Quantos carros existem na imagem?"},
                {
                    "type": "image_url",
                    "image_url": f"data:image/jpeg;base64,{img_base64}",
                },
            ],
        ),
    ]
)

# Gere os prompts/mensagens no formato correto
messages = template.format_messages()

# Inicialize o modelo Databricks via LangChain
llm = ChatDatabricks(endpoint="databricks-llama-4-maverick")

with mlflow.start_run(run_name="inferência_multimodal"):
    resposta = llm.invoke(messages)

    # Salve a resposta como um artefato do MLflow
    mlflow.log_dict({"resultado": str(resposta)}, "resultado.json")
    resposta
# Out:
# Trace(request_id=tr-6b497ff7018d45d2a8270e46ed87db07)
